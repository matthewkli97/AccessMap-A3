# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import sys
import argparse
import overpass


# %matplotlib inline

# %%
import json
json1_file = open('testFeatureMapping.json')
json1_str = json1_file.read()
mapping = json.loads(json1_str)
mapping
# Out:
# {'HEIGHT_DIF': {'target': 'displacement'},
#  'LEVEL_DIFF': {'categoryMap': {'SETTLING': '2', 'UPLIFT': '1'},
#   'target': 'TestTarget'}}

# %%
# Replace with inline add
observations = gpd.read_file('../data/SidewalkObservations/SidewalkObservations.shp')

# %%
testObs = observations.head(50)
testObs
# Out:
#     OBJECTID SIDEWALK_U  OBSERV_TYP  OBSTRUCTIO  CLEARANCE_   TREE_UNITI  \
# 0          1  SDW-44610    SURFCOND
# 1          2  SDW-44610  HEIGHTDIFF                          TRE-1067558
# 2          3  SDW-44610  HEIGHTDIFF                          TRE-1067558
# 3          4  SDW-44610  HEIGHTDIFF
# 4          5  SDW-44610  HEIGHTDIFF
# 5          6  SDW-44610  HEIGHTDIFF
# 6          7  SDW-44610  HEIGHTDIFF
# 7          8  SDW-44610    SURFCOND
# 8          9  SDW-44610  HEIGHTDIFF                          TRE-1067604
# 9         10  SDW-44610  HEIGHTDIFF                          TRE-1067568
# 10        11  SDW-44610  HEIGHTDIFF
# 11        12  SDW-31101    OBSTRUCT  VEG-PLTSTR  HORIZONTAL
# 12        13  SDW-31101  HEIGHTDIFF
# 13        14  SDW-31101    SURFCOND
# 14        15  SDW-31101  HEIGHTDIFF
# 15        16  SDW-31101    SURFCOND                          TRE-1063544
# 16        17  SDW-44609    SURFCOND
# 17        18  SDW-44609  HEIGHTDIFF                          TRE-1067640
# 18        19  SDW-44609  HEIGHTDIFF
# 19        20  SDW-31098  HEIGHTDIFF                                TRE-0
# 20        21  SDW-31098  HEIGHTDIFF
# 21        22  SDW-31098    SURFCOND
# 22        23  SDW-44756  HEIGHTDIFF
# 23        24  SDW-44756  HEIGHTDIFF
# 24        25  SDW-44756  HEIGHTDIFF                                TRE-0
# 25        26  SDW-44756  HEIGHTDIFF                                TRE-0
# 26        27  SDW-44756  HEIGHTDIFF
# 27        28  SDW-44756  HEIGHTDIFF
# 28        29  SDW-44756    SURFCOND
# 29        30  SDW-44756    SURFCOND
# 30        31  SDW-44756    SURFCOND
# 31        32  SDW-44756  HEIGHTDIFF
# 32        33  SDW-44756  HEIGHTDIFF
# 33        34  SDW-30592    SURFCOND
# 34        35  SDW-30592    SURFCOND
# 35        36  SDW-30592  HEIGHTDIFF
# 36        37  SDW-30592    SURFCOND                                TRE-0
# 37        38  SDW-30592  HEIGHTDIFF                                TRE-0
# 38        39  SDW-30592    SURFCOND
# 39        40  SDW-30592    SURFCOND
# 40        41  SDW-30592  HEIGHTDIFF
# 41        42  SDW-30592  HEIGHTDIFF
# 42        43  SDW-44612  HEIGHTDIFF
# 43        44  SDW-44612  HEIGHTDIFF
# 44        45  SDW-44612  HEIGHTDIFF                                TRE-0
# 45        46  SDW-44612  HEIGHTDIFF
# 46        47  SDW-44612  HEIGHTDIFF
# 47        48  SDW-31225    SURFCOND
# 48        49  SDW-31225  HEIGHTDIFF
# 49        50  SDW-31225    SURFCOND
#
#    MINIMUM_WI LEVEL_DIFF UTILITY_OW ISOLATED_C FAILING_SH SURFACE_CO  \
# 0                                                           CRACK>72
# 1                 UPLIFT
# 2                 UPLIFT
# 3                 UPLIFT
# 4               SETTLING
# 5               SETTLING
# 6                 UPLIFT
# 7                                                           CRACK>72
# 8                 UPLIFT
# 9                 UPLIFT
# 10                UPLIFT
# 11          0
# 12                UPLIFT
# 13                                                          CRACK>72
# 14              SETTLING
# 15                                                          CRACK>72
# 16                                                              MOSS
# 17                UPLIFT
# 18              SETTLING
# 19                UPLIFT
# 20                UPLIFT
# 21                                                          CRACK>72
# 22              SETTLING
# 23                UPLIFT
# 24                UPLIFT
# 25                UPLIFT
# 26                UPLIFT
# 27                UPLIFT                   5.4
# 28                                                               GAP
# 29                                                               GAP
# 30                                                          CRACK>72
# 31              SETTLING
# 32                UPLIFT
# 33                                                          CRACK>72
# 34                                                          CRACK>72
# 35                UPLIFT
# 36                                                          CRACK<72
# 37                UPLIFT
# 38                                                               GAP
# 39                                                          CRACK>72
# 40                UPLIFT
# 41              SETTLING
# 42                UPLIFT
# 43                UPLIFT                                Y
# 44                UPLIFT                                Y
# 45              SETTLING
# 46              SETTLING
# 47                                                          CRACK>72
# 48                UPLIFT
# 49                                                               GAP
#
#    OTHER_FEAT HEIGHT_DIF                              GlobalID  \
# 0                         d01c130e-e5ff-4105-9e70-cd304fc1991d
# 1                   0.61  4dd58259-caab-4c0a-9e38-24463d6b2bed
# 2                   1.33  5ca774c2-b8d7-4117-8823-fc4390800370
# 3                   0.73  e0b5e922-07d7-4f04-91e1-e0989a35cc71
# 4                    1.7  6cf3980f-a5f1-487a-bb28-06de9b686f14
# 5                   1.67  204c556e-bfc0-4208-887a-31d8bcd1153c
# 6                   1.58  4442d60f-bd98-441c-bd90-a336504af00c
# 7                         cd3f7a2e-3567-4e2f-845c-4a87c03a51d9
# 8                   0.73  3fcd909b-42d7-49de-ad8d-2eddcbe6ad8f
# 9                    1.1  a8eed6cb-1eeb-4219-8c74-256b4f150211
# 10                  1.14  c84e24d6-638a-4552-94ef-9a0cf48334cf
# 11                        9c57b9f7-2e69-410f-beeb-506bc40ba986
# 12                  1.11  cba4f536-fe6c-4a16-a141-d2c092a22211
# 13                        982e2da7-80a1-4799-802c-26ba99571611
# 14                  2.32  ae790d55-5385-4037-afb4-182b14c847c7
# 15                        3f566479-7622-4465-91cf-0ab156d219e0
# 16                        2b1818b8-84ac-457d-a6ee-eac6504031ac
# 17                  0.64  78d31db9-1f73-4378-9b75-5fd92d5312a5
# 18                  0.61  0b48a77f-fd84-4826-a064-0c1a24899f78
# 19                  0.64  3c23d575-3804-4773-aeeb-abbbc3ba50ab
# 20                  0.59  a39bd4c5-4dae-4ebe-a127-f801b3a146c9
# 21                        eefcecc8-5d57-4415-b585-b0ec9f9bf5b1
# 22                  0.92  9b47dd22-df7e-4242-a37f-52ecdfef0766
# 23                  0.78  2444091d-f2da-4d16-b1b4-208462daac9b
# 24                  1.74  da256cf1-34bc-4b78-927d-d181928ae9c0
# 25                  2.24  c334ba3c-d297-495c-aa3e-c3b88aff5780
# 26                  0.78  82663316-15db-454d-8ea3-b339f473272a
# 29   POINT (-122.3275270777125 47.5541950214917)
# 30   POINT (-122.3274529708916 47.5541981169218)
# 31   POINT (-122.3273629799281 47.5541880547238)
# 32  POINT (-122.3271388959378 47.55420192563269)
# 33   POINT (-122.326375647963 47.55418702391933)
# 34  POINT (-122.3260604168305 47.55417858589328)
# 35   POINT (-122.325832719739 47.55419052163838)
# 36  POINT (-122.3257975997642 47.55419389930886)
# 37  POINT (-122.3257752687792 47.55419407017497)
# 38  POINT (-122.3257008993105 47.55419300992711)
# 39  POINT (-122.3256248142526 47.55419501102645)
# 40  POINT (-122.3255273159449 47.55419934519368)
# 41  POINT (-122.3254657087771 47.55420458362136)
# 42  POINT (-122.3252644600528 47.55418027581114)
# 43  POINT (-122.3252305131441 47.55417960587113)
# 44  POINT (-122.3251849993458 47.55417122337479)
# 45  POINT (-122.3250772279432 47.55417882262164)
# 46  POINT (-122.3250184504037 47.55417080484908)
# 47  POINT (-122.3247868609196 47.55405552581998)
# 48   POINT (-122.3248223149559 47.5540484080113)
# 49  POINT (-122.3251050693825 47.55405706249096)

# %%
# Create a bounding box around the data

bounds = testObs.total_bounds
bounds
# Out:
# array([-122.33386806,   47.55404841, -122.32478686,   47.55423716])

# %%
# Create an overpass reference and get OSM 
# map_query(e , n, s, w)
# bounds -> minx, miny, maxx, maxy

api = overpass.API()
map_query = overpass.MapQuery(bounds[1], bounds[0], bounds[3], bounds[2])
response = api.Get(map_query)

# %%
response
# Out:
# {"features": [{"geometry": {"coordinates": [-122.3309183, 47.5541492], "type": "Point"}, "id": 53082208, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3254314, 47.5541215], "type": "Point"}, "id": 53082276, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3324104, 47.5541556], "type": "Point"}, "id": 53089317, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3295375, 47.5541352], "type": "Point"}, "id": 53089318, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3283522, 47.5541358], "type": "Point"}, "id": 53089320, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3269162, 47.5541266], "type": "Point"}, "id": 53089322, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.325265, 47.5541994], "type": "Point"}, "id": 2349883493, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3251705, 47.5542015], "type": "Point"}, "id": 2349883494, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3298475, 47.554227], "type": "Point"}, "id": 2349883499, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3300685, 47.5542275], "type": "Point"}, "id": 2349883500, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3291753, 47.5542332], "type": "Point"}, "id": 2349883501, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3293105, 47.5542339], "type": "Point"}, "id": 2349883502, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3252043, 47.554236], "type": "Point"}, "id": 2349883503, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3251722, 47.5542367], "type": "Point"}, "id": 2349883504, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.33018, 47.5540583], "type": "Point"}, "id": 2396886938, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3297597, 47.5540589], "type": "Point"}, "id": 2396886939, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3303333, 47.5540661], "type": "Point"}, "id": 2396886940, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3305899, 47.5540684], "type": "Point"}, "id": 2396886941, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3319059, 47.5540727], "type": "Point"}, "id": 2396886942, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3322509, 47.5540741], "type": "Point"}, "id": 2396886943, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3333038, 47.5540763], "type": "Point"}, "id": 2396886944, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3326287, 47.5540767], "type": "Point"}, "id": 2396886945, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates": [-122.3335032, 47.5540774], "type": "Point"}, "id": 2396886946, "properties": {}, "type": "Feature"}, {"geometry": {"coordinates":
}, "type": "Feature"},
#  {"geometry": {"coordinates": [[-122.3326332, 47.5538046], [-122.3340044, 47.5538119], [-122.3340023, 47.5539962], [-122.3338963, 47.5539956], [-122.3338634, 47.5539685], [-122.3335045, 47.5539666], [-122.3335032, 47.5540774], [-122.3333038, 47.5540763], [-122.3333042, 47.5540371], [-122.3332371, 47.5540368], [-122.3332377, 47.553982], [-122.332791, 47.5539796], [-122.3327899, 47.5540776], [-122.3326287, 47.5540767], [-122.3326296, 47.5540011], [-122.3326394, 47.5540012], [-122.3326397, 47.5539796], [-122.3326308, 47.5539795], [-122.3326313, 47.5539355], [-122.3325525, 47.5539351], [-122.3326001, 47.5538462], [-122.3326327, 47.5538464], [-122.3326332, 47.5538046]], "type": "LineString"}, "properties": {"building": "yes", "id": 231286775, "source": "data.seattle.gov"}, "type": "Feature"},
#  {"geometry": {"coordinates": [[-122.3322534, 47.5538005], [-122.3322509, 47.5540741], [-122.3319059, 47.5540727], [-122.3319084, 47.5537991], [-122.3322534, 47.5538005]], "type": "LineString"}, "properties": {"building": "yes", "id": 231286792, "source": "data.seattle.gov"}, "type": "Feature"},
#  {"geometry": {"coordinates": [[-122.33018, 47.5540583], [-122.3297597, 47.5540589], [-122.3297594, 47.5539729], [-122.3299902, 47.5539725], [-122.3299896, 47.5537902], [-122.3301791, 47.5537899], [-122.33018, 47.5540583]], "type": "LineString"}, "properties": {"building": "yes", "id": 231286807, "source": "data.seattle.gov"}, "type": "Feature"},
#  {"geometry": {"coordinates": [[-122.3323844, 47.5598049], [-122.3323955, 47.5574011], [-122.3323992, 47.5565888], [-122.3324034, 47.5556779], [-122.3324069, 47.5549075], [-122.3324087, 47.5545312], [-122.3324104, 47.5541556], [-122.3324121, 47.5537881], [-122.3324138, 47.5534195], [-122.3324171, 47.5527024], [-122.3324189, 47.5523073], [-122.3324208, 47.5518907], [-122.332425, 47.5514728], [-122.3324289, 47.5510889]], "type": "LineString"}, "properties": {"highway": "residential", "id": 245838593, "name": "2nd Avenue South", "tiger:cfcc": "A41", "tiger:county": "King, WA", "tiger:name_base": "2nd", "tiger:name_direction_suffix": "S", "tiger:name_type": "Ave"}, "type": "Feature"},
#  {"geometry": {"coordinates": [[-122.3269095, 47.5555678], [-122.3269076, 47.5548487], [-122.3269162, 47.5541266], [-122.3269165, 47.5537592], [-122.3269168, 47.5533901]], "type": "LineString"}, "properties": {"highway": "residential", "id": 245838595, "name": "6th Avenue South", "tiger:cfcc": "A41", "tiger:county": "King, WA", "tiger:name_base": "6th", "tiger:name_direction_suffix": "S", "tiger:name_type": "Ave"}, "type": "Feature"},
#  {"geometry": {"coordinates": [[-122.329525, 47.5552926], [-122.3295294, 47.5548888], [-122.3295334, 47.5545168], [-122.3295375, 47.5541352], [-122.3295414, 47.5537692], [-122.3295425, 47.5536656]], "type": "LineString"}, "properties": {"highway": "primary", "id": 428017300, "lanes": "4", "name": "4th Avenue South", "old_ref": "US 99 Business (old US 99;PSH 1)", "tiger:cfcc": "A41", "tiger:county": "King, WA", "tiger:name_base": "4th", "tiger:name_direction_suffix": "S", "tiger:name_type": "Ave"}, "type": "Feature"}]

# %%
OSM = gpd.GeoDataFrame.from_features(response)

# %%
type(OSM.loc[24].highway)
# Out:
# str

# %%
lines = OSM[OSM['highway'] == 'residential']
lines.head()
# Out:
#    addr:city addr:housenumber addr:postcode addr:street building  \
# 24       NaN              NaN           NaN         NaN      NaN
# 25       NaN              NaN           NaN         NaN      NaN
# 26       NaN              NaN           NaN         NaN      NaN
# 27       NaN              NaN           NaN         NaN      NaN
# 35       NaN              NaN           NaN         NaN      NaN
#
#                                              geometry      highway         id  \
# 24  LINESTRING (-122.3309486 47.55868, -122.330927...  residential    6347542
# 25  LINESTRING (-122.3254393 47.5545673, -122.3254...  residential    6347567
# 26  LINESTRING (-122.3373453 47.5541514, -122.3370...  residential    6351218
# 27  LINESTRING (-122.3283623 47.5556615, -122.3283...  residential    6444882
# 35  LINESTRING (-122.3323844 47.5598049, -122.3323...  residential  245838593
#
#    lanes                  name old_ref source tiger:cfcc tiger:county  \
# 24   NaN      3rd Avenue South     NaN    NaN        A41     King, WA
# 25   NaN  Maynard Avenue South     NaN    NaN        A41     King, WA
# 26   NaN  South Brandon Street     NaN    NaN        A41     King, WA
# 27   NaN      5th Avenue South     NaN    NaN        A41     King, WA
# 35   NaN      2nd Avenue South     NaN    NaN        A41     King, WA
#
#    tiger:name_base tiger:name_direction_prefix tiger:name_direction_suffix  \
# 24             3rd                         NaN                           S
# 25         Maynard                         NaN                           S
# 26         Brandon                           S                         NaN
# 27             5th                         NaN                           S
# 35             2nd                         NaN                           S
#
#    tiger:name_type
# 24             Ave
# 25             Ave
# 26              St
# 27             Ave
# 35             Ave

# %%
OSM.head()
# Out:
#   addr:city addr:housenumber addr:postcode addr:street building  \
# 0       NaN              NaN           NaN         NaN      NaN
# 1       NaN              NaN           NaN         NaN      NaN
# 2       NaN              NaN           NaN         NaN      NaN
# 3       NaN              NaN           NaN         NaN      NaN
# 4       NaN              NaN           NaN         NaN      NaN
#
#                           geometry highway        id lanes name old_ref  \
# 0  POINT (-122.3309183 47.5541492)     NaN  53082208   NaN  NaN     NaN
# 1  POINT (-122.3254314 47.5541215)     NaN  53082276   NaN  NaN     NaN
# 2  POINT (-122.3324104 47.5541556)     NaN  53089317   NaN  NaN     NaN
# 3  POINT (-122.3295375 47.5541352)     NaN  53089318   NaN  NaN     NaN
# 4  POINT (-122.3283522 47.5541358)     NaN  53089320   NaN  NaN     NaN
#
#   source tiger:cfcc tiger:county tiger:name_base tiger:name_direction_prefix  \
# 0    NaN        NaN          NaN             NaN                         NaN
# 1    NaN        NaN          NaN             NaN                         NaN
# 2    NaN        NaN          NaN             NaN                         NaN
# 3    NaN        NaN          NaN             NaN                         NaN
# 4    NaN        NaN          NaN             NaN                         NaN
#
#   tiger:name_direction_suffix tiger:name_type
# 0                         NaN             NaN
# 1                         NaN             NaN
# 2                         NaN             NaN
# 3                         NaN             NaN
# 4                         NaN             NaN

# %%
OSM.keys()
# Out:
# Index(['addr:city', 'addr:housenumber', 'addr:postcode', 'addr:street',
#        'building', 'geometry', 'highway', 'id', 'lanes', 'name', 'old_ref',
#        'source', 'tiger:cfcc', 'tiger:county', 'tiger:name_base',
#        'tiger:name_direction_prefix', 'tiger:name_direction_suffix',
#        'tiger:name_type'],
#       dtype='object')

# %%
point = testObs.loc[1].geometry
point

# %%
testObs.loc[1]
# Out:
# OBJECTID                                                2
# SIDEWALK_U                                      SDW-44610
# OBSERV_TYP                                     HEIGHTDIFF
# OBSTRUCTIO
# CLEARANCE_
# TREE_UNITI                                    TRE-1067558
# MINIMUM_WI
# LEVEL_DIFF                                         UPLIFT
# UTILITY_OW
# ISOLATED_C
# FAILING_SH
# SURFACE_CO
# OTHER_FEAT
# HEIGHT_DIF                                           0.61
# GlobalID             4dd58259-caab-4c0a-9e38-24463d6b2bed
# geometry      POINT (-122.3335182104243 47.5542197502451)
# Name: 1, dtype: object

# %%
mylist = [x.object for x in lines.sindex.nearest(point.bounds, 10, objects=True)]

distances = lines.loc[mylist].distance(point)
distances
# Out:
# 26    0.000053
# 32    0.000143
# 35    0.001108
# 33    0.001276
# 24    0.002601
# 31    0.002932
# 34    0.003342
# 30    0.003450
# 37    0.003981
# 28    0.004208
# dtype: float64

# %%
nearestIndex = distances.idxmin()
nearestIndex
# Out:
# 26

# %%
sidewalk_geom = lines.loc[nearestIndex].geometry
sidewalk_geom

# %%
# Check shapely manual
distance_along = sidewalk_geom.project(point)
sidewalk_point = sidewalk_geom.interpolate(distance_along)
sidewalk_point

# %%
keys = testObs.loc[1].keys()
keys
# Out:
# Index(['OBJECTID', 'SIDEWALK_U', 'OBSERV_TYP', 'OBSTRUCTIO', 'CLEARANCE_',
#        'TREE_UNITI', 'MINIMUM_WI', 'LEVEL_DIFF', 'UTILITY_OW', 'ISOLATED_C',
#        'FAILING_SH', 'SURFACE_CO', 'OTHER_FEAT', 'HEIGHT_DIF', 'GlobalID',
#        'geometry'],
#       dtype='object')

# %%
#mappingDataframe = gpd.GeoDataFrame({'geometry': [sidewalk_point]})

mappingDict = {}
ref = 0

for key in keys:
    if key in mapping:
        if 'categoryMap' in mapping[key]:
            value = testObs.loc[1][key]
            mappedValue = mapping[key]["categoryMap"][value]
            mappingDict[mapping[key]["target"]] = [mappedValue]
        else:
            value = testObs.loc[1][key]
            mappingDict[mapping[key]["target"]] = [value]
            
        mappingDict['id'] = ref
        mappingDict['geometry'] = [sidewalk_point]
        ref = ref - 1
        #tempFrame = pd.DataFrame.from_dict(mappingDict)
        #gpd.GeoDataFrame(mappingDict)   
    
print(mappingDict)
# Out:
# {'TestTarget': ['1'], 'id': -1, 'geometry': [<shapely.geometry.point.Point object at 0x12c9717f0>], 'displacement': ['0.61']}

# %%
gpd.GeoDataFrame(mappingDict)
# Out:
#   TestTarget displacement                                     geometry  id
# 0          1         0.61  POINT (-122.333518728589 47.55416635572517)  -1

# %%
testDataFrame = gpd.GeoDataFrame()

gpd.GeoDataFrame(pd.concat([testDataFrame, 
                            gpd.GeoDataFrame(mappingDict)
                            ], ignore_index=True))
# Out:
#   TestTarget displacement                                     geometry  id
# 0          1         0.61  POINT (-122.333518728589 47.55416635572517)  -1

# %%
gpd.GeoDataFrame(testDataFrame)
# Out:
#   addr:city addr:housenumber addr:postcode addr:street building  \
# 1       NaN              NaN           NaN         NaN      NaN
#
#                           geometry highway        id lanes name old_ref  \
# 1  POINT (-122.3254314 47.5541215)     NaN  53082276   NaN  NaN     NaN
#
#   source tiger:cfcc tiger:county tiger:name_base tiger:name_direction_prefix  \
# 1    NaN        NaN          NaN             NaN                         NaN
#
#   tiger:name_direction_suffix tiger:name_type
# 1                         NaN             NaN

# %%
gpd.GeoDataFrame({'geometry': [sidewalk_point], 'hello' : 'world'})
# Out:
#                                       geometry  hello
# 0  POINT (-122.333518728589 47.55416635572517)  world
